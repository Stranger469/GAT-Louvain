# %%
import os
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# os.environ['comspec']='powershell.exe'
# os.getenv('comspec')
# Out:
# 'powershell.exe'

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
# !python -W ignore -m dgrec.train --model attn --dropout 0.2 --embu 100 --lr 0.002 --embi 100 --samples1 10 --samples2 5
# Out:
# ^C

# %%
# !python -W ignore -m dgrec.test --model attn --dropout 0.2 --embu 100 --lr 0.002 --embi 100 --samples1 10 --samples2 5 --dataset 3

# %%
# !python -W ignore -m dgrec.test --model attn --dropout 0.2 --embu 100 --lr 0.002 --embi 100 --samples1 10 --samples2 5 --dataset 3
# Out:
# Active code page: 65001
# C:\Users\Ricar\OneDrive\Social_RM
# 0
# Loading data..
# Done loading data..
# 2021-01-21 01:26:03.796397: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-01-21 01:26:12.092355: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-01-21 01:26:12.095291: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library nvcuda.dll
# 2021-01-21 01:26:12.125811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 3090 computeCapability: 8.6
# ...

# %%
from tensorflow.python.client import device_lib
import tensorflow as tf
device_lib.list_local_devices()
tf.__version__
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5211341895169825253,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 22881945600
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 14422639867775243526
#  physical_device_desc: "device: 0, name: GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6"]
# '2.4.0'

# %%
os.getcwd() + '\\save'
# Out:
# 'C:\\Users\\Ricar\\OneDrive\\Social_RM\\save'

# %%
a
# Out:
# 0
